# %%
def Euler(f,a,b,N,alpha):
  h=(b-a)/N
  w=[]
  w.append(alpha)
  t=a
  for i in range(1,N+1):
    w.append(w[i-1]+h*f(t,w[i-1]))
    t=a+i*h
  return w

# %%
a=0
b=2
alpha=0.5
N=10
def f(t,y):
  return y-t**2+1

# %%
Euler(f,a,b,N,alpha)
# Out:
# [0.5,
#  0.8,
#  1.1520000000000001,
#  1.5504000000000002,
#  1.9884800000000002,
#  2.4581760000000004,
#  2.9498112000000005,
#  3.4517734400000006,
#  3.9501281280000007,
#  4.428153753600001,
#  4.865784504320001]
